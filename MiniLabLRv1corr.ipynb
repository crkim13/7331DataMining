# %% [markdown]
# # Mini-Project: SVM & LR Classification
# ### Ryan Bass, Brett Benefield, Cho Kim, Nicole Wittlin
#
# <span style="color: blue">Remove all blue text before submitting</span>

# %%
# %matplotlib inline
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True) # one of the many color mappings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from IPython.display import HTML, display

# %%
verboseStatus = False

# %%
# Brett's directory
# Desktop
#%cd "C:\Sandbox\SMU\dataMining\ChoRepo\EducationDataNC\2017\Machine Learning Datasets"
# Laptop
# %cd "C:\sandbox\SMU\dataMining\choNotebook\EducationDataNC\2017\Machine Learning Datasets"

# Ryan's directory
#%cd "C:\Users\Clovis\Documents\7331DataMining\EducationDataNC\2017\Machine Learning Datasets"

# Cho's directory. Either uncomment the cd statement above or make your own cd.
#%cd "/Users/chostone/Documents/Data Mining/7331DataMining/EducationDataNC/2017/Machine Learning Datasets"

# NW directorY 
# %cd C:\Users\Nicole Wittlin\Documents\Classes\MSDS7331\MiniLab"
dfPublicHS = pd.read_csv("PublicHighSchools2017_ML.csv")

print('********* Initial Values Before Cleaning *******************')
dfPublicHS.info(verbose = verboseStatus)
# Out:
# C:\Users\Nicole Wittlin\Documents\Classes\MSDS7331\MiniLab
# ********* Initial Values Before Cleaning *******************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Columns: 403 entries, student_num to unit_code
# dtypes: float64(322), int64(81)
# memory usage: 1.4 MB

# %%
# store all column names to a list
colNames = dfPublicHS.columns.tolist()

# Create correlation matrix
dfCorr = dfPublicHS[colNames].corr('pearson').abs()

# print correlation matrix
dfCorr
# Out:
#                                                   student_num  \
# student_num                                          1.000000
# lea_avg_student_num                                  0.577813
# st_avg_student_num                                   0.158654
# 09_Size                                              0.482427
# 10_Size                                              0.545790
# 11_Size                                              0.622973
# 12_Size                                              0.602696
# Biology_Size                                         0.651012
# English II_Size                                      0.542595
# Math I_Size                                          0.504443
# lea_total_expense_num                                0.305902
# lea_salary_expense_pct                               0.272729
# lea_services_expense_pct                             0.148452
# lea_supplies_expense_pct                             0.258329
# lea_instruct_equip_exp_pct                           0.096350
# lea_federal_perpupil_num                             0.327924
# lea_local_perpupil_num                               0.112316
# lea_state_perpupil_num                               0.378838
# SPG Score                                            0.162955
# EVAAS Growth Score                                   0.124730
# NC Math 1 Score                                      0.067739
# English II Score                                     0.054238
# Biology Score                                        0.000771
# ACT Score                                            0.063556
# ACT WorkKeys Score                                   0.471681
# Passing NC Math 3                                    0.125324
# 4-Year Cohort Graduation Rate Score                  0.076005
# ACTMath_ACTBenchmark_All                             0.045923
# ACTScience_ACTBenchmark_All                          0.058430
# ACTWorkKeys_SilverPlus_All                           0.557737
# ...                                                       ...
# grades_BYOD_9:11:12                                  0.018345
# grades_BYOD_PK:9:10:11:12                            0.017658
# _1_to_1_access_Yes                                   0.215481
# grades_1_to_1_access_10:11:12                        0.017794
# grades_1_to_1_access_10:11:12:13                     0.067314
# grades_1_to_1_access_11                              0.046379
# grades_1_to_1_access_11:12                           0.055883
# grades_1_to_1_access_11:12:13                        0.070127
# grades_1_to_1_access_6:07:08                         0.022898
# grades_1_to_1_access_6:7:8:9:10:11:12                0.076214
# grades_1_to_1_access_6:7:8:9:10:11:12:13             0.067866
# grades_1_to_1_access_9                               0.041793
# grades_1_to_1_access_9:10                            0.060807
# grades_1_to_1_access_9:10:11                         0.024031
# grades_1_to_1_access_9:10:11:12                      0.032333
# grades_1_to_1_access_9:10:11:12:13                   0.307202
# grades_1_to_1_access_9:11:12:13                      0.048716
# SRC_devices_sent_home_Yes                            0.261738
# SRC_Grades_Devices_Sent_Home_10:11:12                0.017058
# SRC_Grades_Devices_Sent_Home_10:11:12:13             0.059043
# SRC_Grades_Devices_Sent_Home_6:07:08                 0.006434
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12        0.068748
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13     0.050118
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13         0.053001
# SRC_Grades_Devices_Sent_Home_9:10                    0.038277
# SRC_Grades_Devices_Sent_Home_9:10:11                 0.020877
# SRC_Grades_Devices_Sent_Home_9:10:11:12              0.044087
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13           0.307002
# SRC_Grades_Devices_Sent_Home_9:10:12                 0.040069
# unit_code                                            0.095413
#
#                                                   lea_avg_student_num  \
# student_num                                                  0.577813
# lea_avg_student_num                                          1.000000
# st_avg_student_num                                           0.266009
# 09_Size                                                      0.227217
# 10_Size                                                      0.256996
# 11_Size                                                      0.256629
# 12_Size                                                      0.241507
# Biology_Size                                                 0.415685
# English II_Size                                              0.292036
# Math I_Size                                                  0.272326
# lea_total_expense_num                                        0.531835
# lea_salary_expense_pct                                       0.432102
# lea_services_expense_pct                                     0.239948
# lea_supplies_expense_pct                                     0.398177
# lea_instruct_equip_exp_pct                                   0.164217
# lea_federal_perpupil_num                                     0.528984
# lea_local_perpupil_num                                       0.134829
# lea_state_perpupil_num                                       0.625041
# SPG Score                                                    0.157344
# EVAAS Growth Score                                           0.075575
# NC Math 1 Score                                              0.114109
# English II Score                                             0.073360
# Biology Score                                                0.112051
# ACT Score                                                    0.171908
# ACT WorkKeys Score                                           0.149241
# Passing NC Math 3                                            0.025705
# 4-Year Cohort Graduation Rate Score                          0.064587
# ACTMath_ACTBenchmark_All                                     0.292394
# ACTScience_ACTBenchmark_All                                  0.279869
# ACTWorkKeys_SilverPlus_All                                   0.167149
# ...                                                               ...
# grades_BYOD_9:11:12                                          0.019623
# grades_BYOD_PK:9:10:11:12                                    0.030513
# _1_to_1_access_Yes                                           0.138951
# grades_1_to_1_access_10:11:12                                0.012307
# grades_1_to_1_access_10:11:12:13                             0.099876
# grades_1_to_1_access_11                                      0.071297
# grades_1_to_1_access_11:12                                   0.001036
# grades_1_to_1_access_11:12:13                                0.042472
# grades_1_to_1_access_6:07:08                                 0.095443
# grades_1_to_1_access_6:7:8:9:10:11:12                        0.128875
# grades_1_to_1_access_6:7:8:9:10:11:12:13                     0.107865
# grades_1_to_1_access_9                                       0.019566
# grades_1_to_1_access_9:10                                    0.018324
# grades_1_to_1_access_9:10:11                                 0.133189
# grades_1_to_1_access_9:10:11:12                              0.067447
# grades_1_to_1_access_9:10:11:12:13                           0.109319
# grades_1_to_1_access_9:11:12:13                              0.042204
# SRC_devices_sent_home_Yes                                    0.271162
# SRC_Grades_Devices_Sent_Home_10:11:12                        0.056482
# SRC_Grades_Devices_Sent_Home_10:11:12:13                     0.058479
# SRC_Grades_Devices_Sent_Home_6:07:08                         0.059568
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                0.109862
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13             0.081064
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                 0.083629
# SRC_Grades_Devices_Sent_Home_9:10                            0.018843
# SRC_Grades_Devices_Sent_Home_9:10:11                         0.060824
# SRC_Grades_Devices_Sent_Home_9:10:11:12                      0.172195
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                   0.116165
# SRC_Grades_Devices_Sent_Home_9:10:12                         0.064520
# unit_code                                                    0.169113
#
#                                                   st_avg_student_num  \
# student_num                                                 0.158654
# lea_avg_student_num                                         0.266009
# st_avg_student_num                                          1.000000
# 09_Size                                                     0.133943
# 10_Size                                                     0.113514
# 11_Size                                                     0.185630
# 12_Size                                                     0.213359
# Biology_Size                                                0.229118
# English II_Size                                             0.171302
# Math I_Size                                                 0.115240
# lea_total_expense_num                                       0.148966
# lea_salary_expense_pct                                      0.029992
# lea_services_expense_pct                                    0.122537
# lea_supplies_expense_pct                                    0.072659
# lea_instruct_equip_exp_pct                                  0.040190
# lea_federal_perpupil_num                                    0.019623
# lea_local_perpupil_num                                      0.057118
# lea_state_perpupil_num                                      0.145258
# SPG Score                                                   0.097677
# EVAAS Growth Score                                          0.064667
# NC Math 1 Score                                             0.055513
# English II Score                                            0.032049
# Biology Score                                               0.051688
# ACT Score                                                   0.065058
# ACT WorkKeys Score                                          0.055209
# Passing NC Math 3                                           0.040323
# 4-Year Cohort Graduation Rate Score                         0.023739
# ACTMath_ACTBenchmark_All                                    0.104034
# ACTScience_ACTBenchmark_All                                 0.114835
# ACTWorkKeys_SilverPlus_All                                  0.128400
# ...                                                              ...
# grades_BYOD_9:11:12                                         0.013155
# grades_BYOD_PK:9:10:11:12                                   0.009292
# _1_to_1_access_Yes                                          0.098058
# grades_1_to_1_access_10:11:12                               0.018644
# grades_1_to_1_access_10:11:12:13                            0.179979
# grades_1_to_1_access_11                                     0.009292
# grades_1_to_1_access_11:12                                  0.009292
# grades_1_to_1_access_11:12:13                               0.013155
# grades_1_to_1_access_6:07:08                                0.142008
# grades_1_to_1_access_6:7:8:9:10:11:12                       0.528793
# grades_1_to_1_access_6:7:8:9:10:11:12:13                    0.373113
# grades_1_to_1_access_9                                      0.033941
# grades_1_to_1_access_9:10                                   0.013155
# grades_1_to_1_access_9:10:11                                0.032574
# grades_1_to_1_access_9:10:11:12                             0.059222
# grades_1_to_1_access_9:10:11:12:13                          0.058825
# grades_1_to_1_access_9:11:12:13                             0.009292
# SRC_devices_sent_home_Yes                                   0.073057
# SRC_Grades_Devices_Sent_Home_10:11:12                       0.013155
# SRC_Grades_Devices_Sent_Home_10:11:12:13                    0.179979
# SRC_Grades_Devices_Sent_Home_6:07:08                        0.083580
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12               0.373113
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13            0.263549
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                0.009292
# SRC_Grades_Devices_Sent_Home_9:10                           0.009292
# SRC_Grades_Devices_Sent_Home_9:10:11                        0.026481
# SRC_Grades_Devices_Sent_Home_9:10:11:12                     0.006265
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                  0.058825
# SRC_Grades_Devices_Sent_Home_9:10:12                        0.009292
# unit_code                                                   0.063130
#
#                                                    09_Size   10_Size  \
# student_num                                       0.482427  0.545790
# lea_avg_student_num                               0.227217  0.256996
# st_avg_student_num                                0.133943  0.113514
# 09_Size                                           1.000000  0.712800
# 10_Size                                           0.712800  1.000000
# 11_Size                                           0.592155  0.633552
# 12_Size                                           0.554159  0.594540
# Biology_Size                                      0.540738  0.594721
# English II_Size                                   0.477195  0.546398
# Math I_Size                                       0.587350  0.479184
# lea_total_expense_num                             0.227731  0.208769
# lea_salary_expense_pct                            0.034538  0.041021
# lea_services_expense_pct                          0.044202  0.004495
# lea_supplies_expense_pct                          0.012246  0.071733
# lea_instruct_equip_exp_pct                        0.007717  0.011885
# lea_federal_perpupil_num                          0.084370  0.148072
# lea_local_perpupil_num                            0.144529  0.041507
# lea_state_perpupil_num                            0.156810  0.191179
# SPG Score                                         0.325669  0.367164
# EVAAS Growth Score                                0.134465  0.090994
# NC Math 1 Score                                   0.073963  0.150220
# English II Score                                  0.098241  0.111991
# Biology Score                                     0.056902  0.109222
# ACT Score                                         0.198474  0.192842
# ACT WorkKeys Score                                0.321433  0.379803
# Passing NC Math 3                                 0.007774  0.099415
# 4-Year Cohort Graduation Rate Score               0.080051  0.012570
# ACTMath_ACTBenchmark_All                          0.134157  0.133410
# ACTScience_ACTBenchmark_All                       0.152575  0.131868
# ACTWorkKeys_SilverPlus_All                        0.402814  0.500243
# ...                                                    ...       ...
# grades_BYOD_9:11:12                               0.001953  0.020940
# grades_BYOD_PK:9:10:11:12                         0.015102  0.017285
# _1_to_1_access_Yes                                0.084936  0.108975
# grades_1_to_1_access_10:11:12                     0.030324  0.020353
# grades_1_to_1_access_10:11:12:13                  0.141949  0.053192
# grades_1_to_1_access_11                           0.100266  0.087442
# grades_1_to_1_access_11:12                        0.100266  0.087442
# grades_1_to_1_access_11:12:13                     0.083617  0.081432
# grades_1_to_1_access_6:07:08                      0.000784  0.024820
# grades_1_to_1_access_6:7:8:9:10:11:12             0.055125  0.047869
# grades_1_to_1_access_6:7:8:9:10:11:12:13          0.025285  0.024951
# grades_1_to_1_access_9                            0.032822  0.071380
# grades_1_to_1_access_9:10                         0.017491  0.035541
# grades_1_to_1_access_9:10:11                      0.096269  0.040195
# grades_1_to_1_access_9:10:11:12                   0.067846  0.078607
# grades_1_to_1_access_9:10:11:12:13                0.184503  0.203723
# grades_1_to_1_access_9:11:12:13                   0.028848  0.027598
# SRC_devices_sent_home_Yes                         0.146402  0.161898
# SRC_Grades_Devices_Sent_Home_10:11:12             0.021380  0.024470
# SRC_Grades_Devices_Sent_Home_10:11:12:13          0.083617  0.010831
# SRC_Grades_Devices_Sent_Home_6:07:08              0.001953  0.042601
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12     0.075839  0.081432
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13  0.009608  0.017624
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13      0.100266  0.017624
# SRC_Grades_Devices_Sent_Home_9:10                 0.031583  0.087442
# SRC_Grades_Devices_Sent_Home_9:10:11              0.066520  0.019057
# SRC_Grades_Devices_Sent_Home_9:10:11:12           0.023474  0.062975
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13        0.251240  0.294168
# SRC_Grades_Devices_Sent_Home_9:10:12              0.015102  0.002324
# unit_code                                         0.050861  0.033635
#
#                                                    11_Size   12_Size  \
# student_num                                       0.622973  0.602696
# lea_avg_student_num                               0.256629  0.241507
# st_avg_student_num                                0.185630  0.213359
# 09_Size                                           0.592155  0.554159
# 10_Size                                           0.633552  0.594540
# 11_Size                                           1.000000  0.790071
# 12_Size                                           0.790071  1.000000
# Biology_Size                                      0.601437  0.548973
# English II_Size                                   0.514401  0.480256
# Math I_Size                                       0.508646  0.486297
# lea_total_expense_num                             0.255827  0.238047
# lea_salary_expense_pct                            0.071372  0.048896
# lea_services_expense_pct                          0.089616  0.069156
# lea_supplies_expense_pct                          0.029843  0.020584
# lea_instruct_equip_exp_pct                        0.021193  0.034020
# lea_federal_perpupil_num                          0.123283  0.103479
# lea_local_perpupil_num                            0.087579  0.092775
# lea_state_perpupil_num                            0.225754  0.205067
# SPG Score                                         0.423974  0.391001
# EVAAS Growth Score                                0.062383  0.030746
# NC Math 1 Score                                   0.243368  0.292550
# English II Score                                  0.216780  0.261620
# Biology Score                                     0.157635  0.194478
# ACT Score                                         0.271237  0.257628
# ACT WorkKeys Score                                0.489460  0.555953
# Passing NC Math 3                                 0.225439  0.273415
# 4-Year Cohort Graduation Rate Score               0.083851  0.124184
# ACTMath_ACTBenchmark_All                          0.223252  0.245046
# ACTScience_ACTBenchmark_All                       0.219820  0.226736
# ACTWorkKeys_SilverPlus_All                        0.594788  0.635452
# ...                                                    ...       ...
# grades_BYOD_9:11:12                               0.010275  0.013259
# grades_BYOD_PK:9:10:11:12                         0.011110  0.001879
# _1_to_1_access_Yes                                0.133907  0.179549
# grades_1_to_1_access_10:11:12                     0.024925  0.016256
# grades_1_to_1_access_10:11:12:13                  0.049164  0.071525
# grades_1_to_1_access_11                           0.089832  0.077970
# grades_1_to_1_access_11:12                        0.089832  0.013092
# grades_1_to_1_access_11:12:13                     0.127178  0.110384
# grades_1_to_1_access_6:07:08                      0.025358  0.083362
# grades_1_to_1_access_6:7:8:9:10:11:12             0.056515  0.128905
# grades_1_to_1_access_6:7:8:9:10:11:12:13          0.127178  0.110384
# grades_1_to_1_access_9                            0.042056  0.033799
# grades_1_to_1_access_9:10                         0.006560  0.000872
# grades_1_to_1_access_9:10:11                      0.099031  0.070734
# grades_1_to_1_access_9:10:11:12                   0.117199  0.124465
# grades_1_to_1_access_9:10:11:12:13                0.345104  0.395401
# grades_1_to_1_access_9:11:12:13                   0.004634  0.077970
# SRC_devices_sent_home_Yes                         0.167766  0.192552
# SRC_Grades_Devices_Sent_Home_10:11:12             0.010275  0.013259
# SRC_Grades_Devices_Sent_Home_10:11:12:13          0.090028  0.110384
# SRC_Grades_Devices_Sent_Home_6:07:08              0.041734  0.046796
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12     0.075168  0.071525
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13  0.089832  0.077970
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13      0.089832  0.077970
# SRC_Grades_Devices_Sent_Home_9:10                 0.016359  0.001879
# SRC_Grades_Devices_Sent_Home_9:10:11              0.059943  0.046245
# SRC_Grades_Devices_Sent_Home_9:10:11:12           0.078185  0.081762
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13        0.330737  0.402232
# SRC_Grades_Devices_Sent_Home_9:10:12              0.000614  0.001879
# unit_code                                         0.000788  0.050470
#
#                                                   Biology_Size  \
# student_num                                           0.651012
# lea_avg_student_num                                   0.415685
# st_avg_student_num                                    0.229118
# 09_Size                                               0.540738
# 10_Size                                               0.594721
# 11_Size                                               0.601437
# 12_Size                                               0.548973
# Biology_Size                                          1.000000
# English II_Size                                       0.728654
# Math I_Size                                           0.599181
# lea_total_expense_num                                 0.308274
# lea_salary_expense_pct                                0.184252
# lea_services_expense_pct                              0.117092
# lea_supplies_expense_pct                              0.162288
# lea_instruct_equip_exp_pct                            0.049186
# lea_federal_perpupil_num                              0.300950
# lea_local_perpupil_num                                0.016488
# lea_state_perpupil_num                                0.315009
# SPG Score                                             0.103902
# EVAAS Growth Score                                    0.259411
# NC Math 1 Score                                       0.110572
# English II Score                                      0.202739
# Biology Score                                         0.264068
# ACT Score                                             0.075584
# ACT WorkKeys Score                                    0.415862
# Passing NC Math 3                                     0.270569
# 4-Year Cohort Graduation Rate Score                   0.242362
# ACTMath_ACTBenchmark_All                              0.113783
# ACTScience_ACTBenchmark_All                           0.130924
# ACTWorkKeys_SilverPlus_All                            0.467530
# ...                                                        ...
# grades_BYOD_9:11:12                                   0.044590
# grades_BYOD_PK:9:10:11:12                             0.023295
# _1_to_1_access_Yes                                    0.166272
# grades_1_to_1_access_10:11:12                         0.014967
# grades_1_to_1_access_10:11:12:13                      0.019269
# grades_1_to_1_access_11                               0.083322
# grades_1_to_1_access_11:12                            0.148932
# grades_1_to_1_access_11:12:13                         0.135377
# grades_1_to_1_access_6:07:08                          0.106665
# grades_1_to_1_access_6:7:8:9:10:11:12                 0.101358
# grades_1_to_1_access_6:7:8:9:10:11:12:13              0.141182
# grades_1_to_1_access_9                                0.113083
# grades_1_to_1_access_9:10                             0.021369
# grades_1_to_1_access_9:10:11                          0.122389
# grades_1_to_1_access_9:10:11:12                       0.008537
# grades_1_to_1_access_9:10:11:12:13                    0.134575
# grades_1_to_1_access_9:11:12:13                       0.050517
# SRC_devices_sent_home_Yes                             0.160389
# SRC_Grades_Devices_Sent_Home_10:11:12                 0.015563
# SRC_Grades_Devices_Sent_Home_10:11:12:13              0.030880
# SRC_Grades_Devices_Sent_Home_6:07:08                  0.025074
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12         0.094739
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13      0.050517
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13          0.050517
# SRC_Grades_Devices_Sent_Home_9:10                     0.025913
# SRC_Grades_Devices_Sent_Home_9:10:11                  0.086837
# SRC_Grades_Devices_Sent_Home_9:10:11:12               0.022969
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13            0.140187
# SRC_Grades_Devices_Sent_Home_9:10:12                  0.017711
# unit_code                                             0.048523
#
#                                                   English II_Size  \
# student_num                                              0.542595
# lea_avg_student_num                                      0.292036
# st_avg_student_num                                       0.171302
# 09_Size                                                  0.477195
# 10_Size                                                  0.546398
# 11_Size                                                  0.514401
# 12_Size                                                  0.480256
# Biology_Size                                             0.728654
# English II_Size                                          1.000000
# Math I_Size                                              0.617556
# lea_total_expense_num                                    0.237974
# lea_salary_expense_pct                                   0.127244
# lea_services_expense_pct                                 0.055843
# lea_supplies_expense_pct                                 0.135416
# lea_instruct_equip_exp_pct                               0.046917
# lea_federal_perpupil_num                                 0.209390
# lea_local_perpupil_num                                   0.008957
# lea_state_perpupil_num                                   0.234048
# SPG Score                                                0.072178
# EVAAS Growth Score                                       0.330367
# NC Math 1 Score                                          0.203560
# English II Score                                         0.354099
# Biology Score                                            0.266747
# ACT Score                                                0.091473
# ACT WorkKeys Score                                       0.347754
# Passing NC Math 3                                        0.265511
# 4-Year Cohort Graduation Rate Score                      0.257383
# ACTMath_ACTBenchmark_All                                 0.139268
# ACTScience_ACTBenchmark_All                              0.150074
# ACTWorkKeys_SilverPlus_All                               0.406208
# ...                                                           ...
# grades_BYOD_9:11:12                                      0.021904
# grades_BYOD_PK:9:10:11:12                                0.056416
# _1_to_1_access_Yes                                       0.118740
# grades_1_to_1_access_10:11:12                            0.055217
# grades_1_to_1_access_10:11:12:13                         0.027700
# grades_1_to_1_access_11                                  0.156495
# grades_1_to_1_access_11:12                               0.156495
# grades_1_to_1_access_11:12:13                            0.111418
# grades_1_to_1_access_6:07:08                             0.124760
# grades_1_to_1_access_6:7:8:9:10:11:12                    0.100400
# grades_1_to_1_access_6:7:8:9:10:11:12:13                 0.053452
# grades_1_to_1_access_9                                   0.090740
# grades_1_to_1_access_9:10                                0.027700
# grades_1_to_1_access_9:10:11                             0.068589
# grades_1_to_1_access_9:10:11:12                          0.049179
# grades_1_to_1_access_9:10:11:12:13                       0.115021
# grades_1_to_1_access_9:11:12:13                          0.033662
# SRC_devices_sent_home_Yes                                0.106889
# SRC_Grades_Devices_Sent_Home_10:11:12                    0.030266
# SRC_Grades_Devices_Sent_Home_10:11:12:13                 0.030266
# SRC_Grades_Devices_Sent_Home_6:07:08                     0.041859
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12            0.111418
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13         0.066417
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13             0.009095
# SRC_Grades_Devices_Sent_Home_9:10                        0.009095
# SRC_Grades_Devices_Sent_Home_9:10:11                     0.064511
# SRC_Grades_Devices_Sent_Home_9:10:11:12                  0.038768
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13               0.130433
# SRC_Grades_Devices_Sent_Home_9:10:12                     0.033662
# unit_code                                                0.050935
#
#                                                   Math I_Size    ...      \
# student_num                                          0.504443    ...
# lea_avg_student_num                                  0.272326    ...
# st_avg_student_num                                   0.115240    ...
# 09_Size                                              0.587350    ...
# 10_Size                                              0.479184    ...
# 11_Size                                              0.508646    ...
# 12_Size                                              0.486297    ...
# Biology_Size                                         0.599181    ...
# English II_Size                                      0.617556    ...
# Math I_Size                                          1.000000    ...
# lea_total_expense_num                                0.234305    ...
# lea_salary_expense_pct                               0.115917    ...
# lea_services_expense_pct                             0.097198    ...
# lea_supplies_expense_pct                             0.101047    ...
# lea_instruct_equip_exp_pct                           0.025092    ...
# lea_federal_perpupil_num                             0.199620    ...
# lea_local_perpupil_num                               0.062546    ...
# lea_state_perpupil_num                               0.189809    ...
# SPG Score                                            0.231014    ...
# EVAAS Growth Score                                   0.247384    ...
# NC Math 1 Score                                      0.106099    ...
# English II Score                                     0.091430    ...
# Biology Score                                        0.076991    ...
# ACT Score                                            0.109441    ...
# ACT WorkKeys Score                                   0.340158    ...
# Passing NC Math 3                                    0.095961    ...
# 4-Year Cohort Graduation Rate Score                  0.081312    ...
# ACTMath_ACTBenchmark_All                             0.075163    ...
# ACTScience_ACTBenchmark_All                          0.088071    ...
# ACTWorkKeys_SilverPlus_All                           0.402149    ...
# ...                                                       ...    ...
# grades_BYOD_9:11:12                                  0.017556    ...
# grades_BYOD_PK:9:10:11:12                            0.041644    ...
# _1_to_1_access_Yes                                   0.082740    ...
# grades_1_to_1_access_10:11:12                        0.087441    ...
# grades_1_to_1_access_10:11:12:13                     0.005986    ...
# grades_1_to_1_access_11                              0.149591    ...
# grades_1_to_1_access_11:12                           0.149591    ...
# grades_1_to_1_access_11:12:13                        0.123496    ...
# grades_1_to_1_access_6:07:08                         0.043173    ...
# grades_1_to_1_access_6:7:8:9:10:11:12                0.091612    ...
# grades_1_to_1_access_6:7:8:9:10:11:12:13             0.005785    ...
# grades_1_to_1_access_9                               0.030628    ...
# grades_1_to_1_access_9:10                            0.041099    ...
# grades_1_to_1_access_9:10:11                         0.063398    ...
# grades_1_to_1_access_9:10:11:12                      0.064839    ...
# grades_1_to_1_access_9:10:11:12:13                   0.146079    ...
# grades_1_to_1_access_9:11:12:13                      0.041502    ...
# SRC_devices_sent_home_Yes                            0.094351    ...
# SRC_Grades_Devices_Sent_Home_10:11:12                0.064641    ...
# SRC_Grades_Devices_Sent_Home_10:11:12:13             0.000100    ...
# SRC_Grades_Devices_Sent_Home_6:07:08                 0.041099    ...
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12        0.088183    ...
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13     0.033329    ...
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13         0.016558    ...
# SRC_Grades_Devices_Sent_Home_9:10                    0.000071    ...
# SRC_Grades_Devices_Sent_Home_9:10:11                 0.015011    ...
# SRC_Grades_Devices_Sent_Home_9:10:11:12              0.016565    ...
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13           0.146079    ...
# SRC_Grades_Devices_Sent_Home_9:10:12                 0.016700    ...
# unit_code                                            0.005566    ...
#
#                                                   SRC_Grades_Devices_Sent_Home_6:07:08  \
# student_num                                                                   0.006434
# lea_avg_student_num                                                           0.059568
# st_avg_student_num                                                            0.083580
# 09_Size                                                                       0.001953
# 10_Size                                                                       0.042601
# 11_Size                                                                       0.041734
# 12_Size                                                                       0.046796
# Biology_Size                                                                  0.025074
# English II_Size                                                               0.041859
# Math I_Size                                                                   0.041099
# lea_total_expense_num                                                         0.230740
# lea_salary_expense_pct                                                        0.066425
# lea_services_expense_pct                                                      0.124646
# lea_supplies_expense_pct                                                      0.008467
# lea_instruct_equip_exp_pct                                                    0.045747
# lea_federal_perpupil_num                                                      0.063066
# lea_local_perpupil_num                                                        0.088025
# lea_state_perpupil_num                                                        0.213643
# SPG Score                                                                     0.038605
# EVAAS Growth Score                                                            0.009408
# NC Math 1 Score                                                               0.036147
# English II Score                                                              0.074425
# Biology Score                                                                 0.066294
# ACT Score                                                                     0.068847
# ACT WorkKeys Score                                                            0.044176
# Passing NC Math 3                                                             0.017013
# 4-Year Cohort Graduation Rate Score                                           0.033888
# ACTMath_ACTBenchmark_All                                                      0.002477
# ACTScience_ACTBenchmark_All                                                   0.004023
# ACTWorkKeys_SilverPlus_All                                                    0.035116
# ...                                                                                ...
# grades_BYOD_9:11:12                                                           0.004274
# grades_BYOD_PK:9:10:11:12                                                     0.003019
# _1_to_1_access_Yes                                                            0.064543
# grades_1_to_1_access_10:11:12                                                 0.006057
# grades_1_to_1_access_10:11:12:13                                              0.004274
# grades_1_to_1_access_11                                                       0.003019
# grades_1_to_1_access_11:12                                                    0.003019
# grades_1_to_1_access_11:12:13                                                 0.004274
# grades_1_to_1_access_6:07:08                                                  0.815624
# grades_1_to_1_access_6:7:8:9:10:11:12                                         0.006057
# grades_1_to_1_access_6:7:8:9:10:11:12:13                                      0.004274
# grades_1_to_1_access_9                                                        0.011026
# grades_1_to_1_access_9:10                                                     0.004274
# grades_1_to_1_access_9:10:11                                                  0.010582
# grades_1_to_1_access_9:10:11:12                                               0.045416
# grades_1_to_1_access_9:10:11:12:13                                            0.019109
# grades_1_to_1_access_9:11:12:13                                               0.003019
# SRC_devices_sent_home_Yes                                                     0.077632
# SRC_Grades_Devices_Sent_Home_10:11:12                                         0.004274
# SRC_Grades_Devices_Sent_Home_10:11:12:13                                      0.004274
# SRC_Grades_Devices_Sent_Home_6:07:08                                          1.000000
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                                 0.004274
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13                              0.003019
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                                  0.003019
# SRC_Grades_Devices_Sent_Home_9:10                                             0.003019
# SRC_Grades_Devices_Sent_Home_9:10:11                                          0.008602
# SRC_Grades_Devices_Sent_Home_9:10:11:12                                       0.039135
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                                    0.019109
# SRC_Grades_Devices_Sent_Home_9:10:12                                          0.003019
# unit_code                                                                     0.015844
#
#                                                   SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12  \
# student_num                                                                            0.068748
# lea_avg_student_num                                                                    0.109862
# st_avg_student_num                                                                     0.373113
# 09_Size                                                                                0.075839
# 10_Size                                                                                0.081432
# 11_Size                                                                                0.075168
# 12_Size                                                                                0.071525
# Biology_Size                                                                           0.094739
# English II_Size                                                                        0.111418
# Math I_Size                                                                            0.088183
# lea_total_expense_num                                                                  0.015249
# lea_salary_expense_pct                                                                 0.054592
# lea_services_expense_pct                                                               0.010240
# lea_supplies_expense_pct                                                               0.081650
# lea_instruct_equip_exp_pct                                                             0.055345
# lea_federal_perpupil_num                                                               0.064990
# lea_local_perpupil_num                                                                 0.103643
# lea_state_perpupil_num                                                                 0.039338
# SPG Score                                                                              0.038404
# EVAAS Growth Score                                                                     0.135946
# NC Math 1 Score                                                                        0.065234
# English II Score                                                                       0.017707
# Biology Score                                                                          0.013258
# ACT Score                                                                              0.011034
# ACT WorkKeys Score                                                                     0.036879
# Passing NC Math 3                                                                      0.015538
# 4-Year Cohort Graduation Rate Score                                                    0.001614
# ACTMath_ACTBenchmark_All                                                               0.015085
# ACTScience_ACTBenchmark_All                                                            0.043092
# ACTWorkKeys_SilverPlus_All                                                             0.028524
# ...                                                                                         ...
# grades_BYOD_9:11:12                                                                    0.004274
# grades_BYOD_PK:9:10:11:12                                                              0.003019
# _1_to_1_access_Yes                                                                     0.064543
# grades_1_to_1_access_10:11:12                                                          0.006057
# grades_1_to_1_access_10:11:12:13                                                       0.004274
# grades_1_to_1_access_11                                                                0.003019
# grades_1_to_1_access_11:12                                                             0.003019
# grades_1_to_1_access_11:12:13                                                          0.004274
# grades_1_to_1_access_6:07:08                                                           0.005240
# grades_1_to_1_access_6:7:8:9:10:11:12                                                  0.705594
# grades_1_to_1_access_6:7:8:9:10:11:12:13                                               0.004274
# grades_1_to_1_access_9                                                                 0.011026
# grades_1_to_1_access_9:10                                                              0.004274
# grades_1_to_1_access_9:10:11                                                           0.010582
# grades_1_to_1_access_9:10:11:12                                                        0.045416
# grades_1_to_1_access_9:10:11:12:13                                                     0.019109
# grades_1_to_1_access_9:11:12:13                                                        0.003019
# SRC_devices_sent_home_Yes                                                              0.077632
# SRC_Grades_Devices_Sent_Home_10:11:12                                                  0.004274
# SRC_Grades_Devices_Sent_Home_10:11:12:13                                               0.004274
# SRC_Grades_Devices_Sent_Home_6:07:08                                                   0.004274
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                                          1.000000
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13                                       0.003019
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                                           0.003019
# SRC_Grades_Devices_Sent_Home_9:10                                                      0.003019
# SRC_Grades_Devices_Sent_Home_9:10:11                                                   0.008602
# SRC_Grades_Devices_Sent_Home_9:10:11:12                                                0.039135
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                                             0.019109
# SRC_Grades_Devices_Sent_Home_9:10:12                                                   0.003019
# unit_code                                                                              0.029750
#
#                                                   SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13  \
# student_num                                                                               0.050118
# lea_avg_student_num                                                                       0.081064
# st_avg_student_num                                                                        0.263549
# 09_Size                                                                                   0.009608
# 10_Size                                                                                   0.017624
# 11_Size                                                                                   0.089832
# 12_Size                                                                                   0.077970
# Biology_Size                                                                              0.050517
# English II_Size                                                                           0.066417
# Math I_Size                                                                               0.033329
# lea_total_expense_num                                                                     0.313993
# ...
# SRC_Grades_Devices_Sent_Home_9:10                                                0.027643
# SRC_Grades_Devices_Sent_Home_9:10:11                                             0.078777
# SRC_Grades_Devices_Sent_Home_9:10:11:12                                          1.000000
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                                       0.174997
# SRC_Grades_Devices_Sent_Home_9:10:12                                             0.027643
# unit_code                                                                        0.167797
#
#                                                   SRC_Grades_Devices_Sent_Home_9:10:11:12:13  \
# student_num                                                                         0.307002
# lea_avg_student_num                                                                 0.116165
# st_avg_student_num                                                                  0.058825
# 09_Size                                                                             0.251240
# 10_Size                                                                             0.294168
# 11_Size                                                                             0.330737
# 12_Size                                                                             0.402232
# Biology_Size                                                                        0.140187
# English II_Size                                                                     0.130433
# Math I_Size                                                                         0.146079
# lea_total_expense_num                                                               0.056637
# lea_salary_expense_pct                                                              0.123881
# lea_services_expense_pct                                                            0.053757
# lea_supplies_expense_pct                                                            0.130739
# lea_instruct_equip_exp_pct                                                          0.049487
# lea_federal_perpupil_num                                                            0.047175
# lea_local_perpupil_num                                                              0.087267
# lea_state_perpupil_num                                                              0.128164
# SPG Score                                                                           0.316431
# EVAAS Growth Score                                                                  0.098728
# NC Math 1 Score                                                                     0.325751
# English II Score                                                                    0.328830
# Biology Score                                                                       0.313749
# ACT Score                                                                           0.340695
# ACT WorkKeys Score                                                                  0.336617
# Passing NC Math 3                                                                   0.069480
# 4-Year Cohort Graduation Rate Score                                                 0.153339
# ACTMath_ACTBenchmark_All                                                            0.218873
# ACTScience_ACTBenchmark_All                                                         0.212753
# ACTWorkKeys_SilverPlus_All                                                          0.401474
# ...                                                                                      ...
# grades_BYOD_9:11:12                                                                 0.019109
# grades_BYOD_PK:9:10:11:12                                                           0.013498
# _1_to_1_access_Yes                                                                  0.288611
# grades_1_to_1_access_10:11:12                                                       0.027083
# grades_1_to_1_access_10:11:12:13                                                    0.102262
# grades_1_to_1_access_11                                                             0.013498
# grades_1_to_1_access_11:12                                                          0.013498
# grades_1_to_1_access_11:12:13                                                       0.019109
# grades_1_to_1_access_6:07:08                                                        0.023429
# grades_1_to_1_access_6:7:8:9:10:11:12                                               0.027083
# grades_1_to_1_access_6:7:8:9:10:11:12:13                                            0.019109
# grades_1_to_1_access_9                                                              0.049303
# grades_1_to_1_access_9:10                                                           0.019109
# grades_1_to_1_access_9:10:11                                                        0.047317
# grades_1_to_1_access_9:10:11:12                                                     0.186222
# grades_1_to_1_access_9:10:11:12:13                                                  0.911991
# grades_1_to_1_access_9:11:12:13                                                     0.157963
# SRC_devices_sent_home_Yes                                                           0.347141
# SRC_Grades_Devices_Sent_Home_10:11:12                                               0.019109
# SRC_Grades_Devices_Sent_Home_10:11:12:13                                            0.019109
# SRC_Grades_Devices_Sent_Home_6:07:08                                                0.019109
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                                       0.019109
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13                                    0.013498
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                                        0.013498
# SRC_Grades_Devices_Sent_Home_9:10                                                   0.013498
# SRC_Grades_Devices_Sent_Home_9:10:11                                                0.038466
# SRC_Grades_Devices_Sent_Home_9:10:11:12                                             0.174997
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                                          1.000000
# SRC_Grades_Devices_Sent_Home_9:10:12                                                0.013498
# unit_code                                                                           0.037190
#
#                                                   SRC_Grades_Devices_Sent_Home_9:10:12  \
# student_num                                                                   0.040069
# lea_avg_student_num                                                           0.064520
# st_avg_student_num                                                            0.009292
# 09_Size                                                                       0.015102
# 10_Size                                                                       0.002324
# 11_Size                                                                       0.000614
# 12_Size                                                                       0.001879
# Biology_Size                                                                  0.017711
# English II_Size                                                               0.033662
# Math I_Size                                                                   0.016700
# lea_total_expense_num                                                         0.137076
# lea_salary_expense_pct                                                        0.029456
# lea_services_expense_pct                                                      0.072978
# lea_supplies_expense_pct                                                      0.012442
# lea_instruct_equip_exp_pct                                                    0.045873
# lea_federal_perpupil_num                                                      0.080523
# lea_local_perpupil_num                                                        0.017064
# lea_state_perpupil_num                                                        0.139663
# SPG Score                                                                     0.002561
# EVAAS Growth Score                                                            0.013786
# NC Math 1 Score                                                               0.007751
# English II Score                                                              0.023050
# Biology Score                                                                 0.017199
# ACT Score                                                                     0.026917
# ACT WorkKeys Score                                                            0.038009
# Passing NC Math 3                                                             0.010975
# 4-Year Cohort Graduation Rate Score                                           0.031856
# ACTMath_ACTBenchmark_All                                                      0.031705
# ACTScience_ACTBenchmark_All                                                   0.025017
# ACTWorkKeys_SilverPlus_All                                                    0.042080
# ...                                                                                ...
# grades_BYOD_9:11:12                                                           0.003019
# grades_BYOD_PK:9:10:11:12                                                     0.002132
# _1_to_1_access_Yes                                                            0.045590
# grades_1_to_1_access_10:11:12                                                 0.004278
# grades_1_to_1_access_10:11:12:13                                              0.003019
# grades_1_to_1_access_11                                                       0.002132
# grades_1_to_1_access_11:12                                                    0.002132
# grades_1_to_1_access_11:12:13                                                 0.003019
# grades_1_to_1_access_6:07:08                                                  0.003701
# grades_1_to_1_access_6:7:8:9:10:11:12                                         0.004278
# grades_1_to_1_access_6:7:8:9:10:11:12:13                                      0.003019
# grades_1_to_1_access_9                                                        0.007788
# grades_1_to_1_access_9:10                                                     0.003019
# grades_1_to_1_access_9:10:11                                                  0.007474
# grades_1_to_1_access_9:10:11:12                                               0.066466
# grades_1_to_1_access_9:10:11:12:13                                            0.013498
# grades_1_to_1_access_9:11:12:13                                               0.002132
# SRC_devices_sent_home_Yes                                                     0.054836
# SRC_Grades_Devices_Sent_Home_10:11:12                                         0.003019
# SRC_Grades_Devices_Sent_Home_10:11:12:13                                      0.003019
# SRC_Grades_Devices_Sent_Home_6:07:08                                          0.003019
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                                 0.003019
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13                              0.002132
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                                  0.002132
# SRC_Grades_Devices_Sent_Home_9:10                                             0.002132
# SRC_Grades_Devices_Sent_Home_9:10:11                                          0.006076
# SRC_Grades_Devices_Sent_Home_9:10:11:12                                       0.027643
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                                    0.013498
# SRC_Grades_Devices_Sent_Home_9:10:12                                          1.000000
# unit_code                                                                     0.001054
#
#                                                   unit_code
# student_num                                        0.095413
# lea_avg_student_num                                0.169113
# st_avg_student_num                                 0.063130
# 09_Size                                            0.050861
# 10_Size                                            0.033635
# 11_Size                                            0.000788
# 12_Size                                            0.050470
# Biology_Size                                       0.048523
# English II_Size                                    0.050935
# Math I_Size                                        0.005566
# lea_total_expense_num                              0.052059
# lea_salary_expense_pct                             0.048904
# lea_services_expense_pct                           0.037762
# lea_supplies_expense_pct                           0.130173
# lea_instruct_equip_exp_pct                         0.000658
# lea_federal_perpupil_num                           0.064738
# lea_local_perpupil_num                             0.078157
# lea_state_perpupil_num                             0.016535
# SPG Score                                          0.014287
# EVAAS Growth Score                                 0.042047
# NC Math 1 Score                                    0.039352
# English II Score                                   0.035330
# Biology Score                                      0.053132
# ACT Score                                          0.022992
# ACT WorkKeys Score                                 0.014394
# Passing NC Math 3                                  0.013172
# 4-Year Cohort Graduation Rate Score                0.006193
# ACTMath_ACTBenchmark_All                           0.039102
# ACTScience_ACTBenchmark_All                        0.040069
# ACTWorkKeys_SilverPlus_All                         0.029180
# ...                                                     ...
# grades_BYOD_9:11:12                                0.069084
# grades_BYOD_PK:9:10:11:12                          0.054357
# _1_to_1_access_Yes                                 0.147584
# grades_1_to_1_access_10:11:12                      0.045419
# grades_1_to_1_access_10:11:12:13                   0.040863
# grades_1_to_1_access_11                            0.014133
# grades_1_to_1_access_11:12                         0.016914
# grades_1_to_1_access_11:12:13                      0.063992
# grades_1_to_1_access_6:07:08                       0.022736
# grades_1_to_1_access_6:7:8:9:10:11:12              0.020972
# grades_1_to_1_access_6:7:8:9:10:11:12:13           0.043177
# grades_1_to_1_access_9                             0.138499
# grades_1_to_1_access_9:10                          0.065615
# grades_1_to_1_access_9:10:11                       0.049606
# grades_1_to_1_access_9:10:11:12                    0.168965
# grades_1_to_1_access_9:10:11:12:13                 0.034736
# grades_1_to_1_access_9:11:12:13                    0.020194
# SRC_devices_sent_home_Yes                          0.122762
# SRC_Grades_Devices_Sent_Home_10:11:12              0.025118
# SRC_Grades_Devices_Sent_Home_10:11:12:13           0.101038
# SRC_Grades_Devices_Sent_Home_6:07:08               0.015844
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12      0.029750
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13   0.005484
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13       0.014966
# SRC_Grades_Devices_Sent_Home_9:10                  0.067599
# SRC_Grades_Devices_Sent_Home_9:10:11               0.040288
# SRC_Grades_Devices_Sent_Home_9:10:11:12            0.167797
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13         0.037190
# SRC_Grades_Devices_Sent_Home_9:10:12               0.001054
# unit_code                                          1.000000
#
# [403 rows x 403 columns]

# %%
## source for code below: https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/ ##

# Select upper triangle of correlation matrix
upper = dfCorr.where(np.triu(np.ones(dfCorr.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.94
to_drop = [column for column in upper.columns if any(upper[column] > 0.94)]
to_drop
print (len(to_drop))
# Out:
# 11

# %%
# code to determine the number of highly correlated variables to drop for given r.
r = .95
while (r >= .80):
    to_drop = [column for column in upper.columns if any(upper[column] > r)]
    print('For r of ', r, 'drop # is:', len(to_drop) )
    r = r-.01
    r = round(r,2)
# print the list of columns to drop for the last iteration of the while loop.    
to_drop
# Out:
# For r of  0.95 drop # is: 0
# For r of  0.94 drop # is: 11
# For r of  0.93 drop # is: 22
# For r of  0.92 drop # is: 28
# For r of  0.91 drop # is: 34
# For r of  0.9 drop # is: 42
# For r of  0.89 drop # is: 51
# For r of  0.88 drop # is: 58
# For r of  0.87 drop # is: 66
# For r of  0.86 drop # is: 72
# For r of  0.85 drop # is: 80
# For r of  0.84 drop # is: 88
# For r of  0.83 drop # is: 99
# For r of  0.82 drop # is: 107
# For r of  0.81 drop # is: 116
# For r of  0.8 drop # is: 124
# ['lea_state_perpupil_num',
#  '4-Year Cohort Graduation Rate Score',
#  'ACTMath_ACTBenchmark_All',
#  'ACTScience_ACTBenchmark_All',
#  'ACTWorkKeys_SilverPlus_All',
#  'ACTWriting_ACTBenchmark_All',
#  'EOCSubjects_CACR_All',
#  'ACTCompositeScore_UNCMin_Female',
#  'ACTEnglish_ACTBenchmark_Female',
#  'ACTMath_ACTBenchmark_Female',
#  'ACTReading_ACTBenchmark_Female',
#  'ACTScience_ACTBenchmark_Female',
#  'ACTWorkKeys_SilverPlus_Female',
#  'EOCBiology_CACR_Female',
#  'EOCEnglish2_CACR_Female',
#  'GraduationRate_5yr_Female',
#  'ACTCompositeScore_UNCMin_Male',
#  'ACTMath_ACTBenchmark_Male',
#  'ACTScience_ACTBenchmark_Male',
#  'ACTWorkKeys_SilverPlus_Male',
#  'ACTWriting_ACTBenchmark_Male',
#  'EOCBiology_CACR_Male',
#  'EOCEnglish2_CACR_Male',
#  'EOCMathI_CACR_Male',
#  'ACTMath_ACTBenchmark_AmericanIndian',
#  'ACTWorkKeys_SilverPlus_AmericanIndian',
#  'ACTWriting_ACTBenchmark_AmericanIndian',
#  'EOCBiology_CACR_AmericanIndian',
#  'EOCEnglish2_CACR_AmericanIndian',
#  'EOCMathI_CACR_AmericanIndian',
#  'GraduationRate_4yr_AmericanIndian',
#  'ACTWriting_ACTBenchmark_Asian',
#  'EOCEnglish2_CACR_Asian',
#  'EOCMathI_CACR_Asian',
#  'ACTEnglish_ACTBenchmark_Black',
#  'ACTMath_ACTBenchmark_Black',
#  'ACTReading_ACTBenchmark_Black',
#  'ACTScience_ACTBenchmark_Black',
#  'ACTWriting_ACTBenchmark_Black',
#  'GraduationRate_5yr_Black',
#  'ACTEnglish_ACTBenchmark_Hispanic',
#  'ACTMath_ACTBenchmark_Hispanic',
#  'ACTReading_ACTBenchmark_Hispanic',
#  'ACTScience_ACTBenchmark_Hispanic',
#  'ACTWriting_ACTBenchmark_Hispanic',
#  'ACTMath_ACTBenchmark_TwoorMoreRaces',
#  'ACTReading_ACTBenchmark_TwoorMoreRaces',
#  'ACTScience_ACTBenchmark_TwoorMoreRaces',
#  'ACTWriting_ACTBenchmark_TwoorMoreRaces',
#  'EOCEnglish2_CACR_TwoorMoreRaces',
#  'ACTMath_ACTBenchmark_White',
#  'ACTScience_ACTBenchmark_White',
#  'ACTSubtests_BenchmarksMet_White',
#  'ACTWorkKeys_SilverPlus_White',
#  'ACTWriting_ACTBenchmark_White',
#  'EOCMathI_CACR_White',
#  'EOCSubjects_CACR_White',
#  'ACTEnglish_ACTBenchmark_EDS',
#  'ACTMath_ACTBenchmark_EDS',
#  'ACTReading_ACTBenchmark_EDS',
#  'ACTScience_ACTBenchmark_EDS',
#  'ACTSubtests_BenchmarksMet_EDS',
#  'ACTWorkKeys_SilverPlus_EDS',
#  'EOCEnglish2_CACR_EDS',
#  'EOCMathI_CACR_EDS',
#  'EOCSubjects_CACR_EDS',
#  'ACTEnglish_ACTBenchmark_LEP',
#  'ACTMath_ACTBenchmark_LEP',
#  'ACTReading_ACTBenchmark_LEP',
#  'ACTScience_ACTBenchmark_LEP',
#  'EOCBiology_GLP_LEP',
#  'EOCEnglish2_GLP_LEP',
#  'EOCMathI_GLP_LEP',
#  'EOCSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_LEP',
#  'ACTEnglish_ACTBenchmark_SWD',
#  'ACTReading_ACTBenchmark_SWD',
#  'ACTScience_ACTBenchmark_SWD',
#  'EOCBiology_GLP_SWD',
#  'EOCEnglish2_GLP_SWD',
#  'EOCMathI_GLP_SWD',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_CACR_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'GraduationRate_5yr_SWD',
#  'ACTMath_ACTBenchmark_AIG',
#  'ACTScience_ACTBenchmark_AIG',
#  'ACTWriting_ACTBenchmark_AIG',
#  'ReadingGr10_pTarget_PctMet',
#  'lea_total_specialized_courses',
#  'st_total_specialized_courses',
#  'F_Female_ENROLL_sch_pct',
#  'M_Male_ENROLL_sch_pct',
#  'st_short_susp_per_c_num',
#  'wap_num',
#  'Accomplished_TCHR_Standard 3_Pct',
#  'Distinguished_TCHR_Standard 3_Pct',
#  'Distinguished_TCHR_Standard 4_Pct',
#  'Distinguished_TCHR_Standard 5_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'Proficient_TCHR_Standard 2_Pct',
#  'Proficient_TCHR_Standard 3_Pct',
#  'Proficient_TCHR_Standard 4_Pct',
#  'Proficient_TCHR_Standard 5_Pct',
#  'AsianMalePct',
#  'BlackFemalePct',
#  'BlackPct',
#  'HispanicPct',
#  'MinorityFemalePct',
#  'MinorityMalePct',
#  'MinorityPct',
#  'PacificIslandPct',
#  'TwoOrMorePct',
#  'Gr_9_Pct_Prof',
#  'MRKT_Concentrator_Ct',
#  'Math SPG Grade_D',
#  'State Gap Compared_Y',
#  'grades_1_to_1_access_6:7:8:9:10:11:12',
#  'SRC_devices_sent_home_Yes',
#  'SRC_Grades_Devices_Sent_Home_6:07:08',
#  'SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_9:10:11',
#  'SRC_Grades_Devices_Sent_Home_9:10:11:12',
#  'SRC_Grades_Devices_Sent_Home_9:10:11:12:13']

# %%
dfDropped = dfPublicHS.drop(to_drop, axis = 1)

# %%
dfDropped.describe()
# Out:
#        student_num  lea_avg_student_num  st_avg_student_num     09_Size  \
# count   470.000000           470.000000          470.000000  470.000000
# mean    834.336170           823.078723          833.417021   18.251064
# std     593.357073           360.428092           97.416634    8.414169
# min       8.000000           105.000000          278.000000    0.000000
# 25%     312.750000           577.000000          853.000000   16.000000
# 50%     758.500000           810.000000          853.000000   20.000000
# 75%    1208.500000           974.000000          853.000000   23.000000
# max    2966.000000          1852.000000          853.000000   94.000000
#
#           10_Size     11_Size     12_Size  Biology_Size  English II_Size  \
# count  470.000000  470.000000  470.000000    470.000000       470.000000
# mean    17.534043   17.117021   15.623404     18.159574        19.110638
# std      9.269129    8.807896    9.262385      5.636281         5.644826
# min      0.000000    0.000000    0.000000      0.000000         0.000000
# 25%     15.000000   14.000000   11.000000     15.000000        17.000000
# 50%     20.000000   20.000000   18.000000     19.000000        20.000000
# 75%     23.000000   24.000000   22.000000     22.000000        23.000000
# max     92.000000   30.000000   36.000000     30.000000        30.000000
#
#        Math I_Size      ...        grades_1_to_1_access_9:10:11:12  \
# count   470.000000      ...                             470.000000
# mean     17.991489      ...                               0.325532
# std       5.559518      ...                               0.469073
# min       0.000000      ...                               0.000000
# 25%      16.000000      ...                               0.000000
# 50%      18.000000      ...                               0.000000
# 75%      21.750000      ...                               1.000000
# max      32.000000      ...                               1.000000
#
#        grades_1_to_1_access_9:10:11:12:13  grades_1_to_1_access_9:11:12:13  \
# count                          470.000000                       470.000000
# mean                             0.078723                         0.002128
# std                              0.269594                         0.046127
# min                              0.000000                         0.000000
# 25%                              0.000000                         0.000000
# 50%                              0.000000                         0.000000
# 75%                              0.000000                         0.000000
# max                              1.000000                         1.000000
#
#        SRC_Grades_Devices_Sent_Home_10:11:12  \
# count                             470.000000
# mean                                0.004255
# std                                 0.065163
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        SRC_Grades_Devices_Sent_Home_10:11:12:13  \
# count                                470.000000
# mean                                   0.004255
# std                                    0.065163
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12  \
# count                                     470.000000
# mean                                        0.004255
# std                                         0.065163
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13  \
# count                                    470.000000
# mean                                       0.002128
# std                                        0.046127
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        SRC_Grades_Devices_Sent_Home_9:10  \
# count                         470.000000
# mean                            0.002128
# std                             0.046127
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             1.000000
#
#        SRC_Grades_Devices_Sent_Home_9:10:12      unit_code
# count                            470.000000     470.000000
# mean                               0.002128  513869.680851
# std                                0.046127  282797.834670
# min                                0.000000   10303.000000
# 25%                                0.000000  280307.000000
# 50%                                0.000000  505332.000000
# 75%                                0.000000  770348.750000
# max                                1.000000  995330.000000
#
# [8 rows x 279 columns]

# %%
colNames = dfDropped.columns.tolist()

# %%
colNames
# Out:
# ['student_num',
#  'lea_avg_student_num',
#  'st_avg_student_num',
#  '09_Size',
#  '10_Size',
#  '11_Size',
#  '12_Size',
#  'Biology_Size',
#  'English II_Size',
#  'Math I_Size',
#  'lea_total_expense_num',
#  'lea_salary_expense_pct',
#  'lea_services_expense_pct',
#  'lea_supplies_expense_pct',
#  'lea_instruct_equip_exp_pct',
#  'lea_federal_perpupil_num',
#  'lea_local_perpupil_num',
#  'SPG Score',
#  'EVAAS Growth Score',
#  'NC Math 1 Score',
#  'English II Score',
#  'Biology Score',
#  'ACT Score',
#  'ACT WorkKeys Score',
#  'Passing NC Math 3',
#  'GraduationRate_5yr_All',
#  'GraduationRate_4yr_Female',
#  'GraduationRate_4yr_Male',
#  'GraduationRate_5yr_Male',
#  'ACTCompositeScore_UNCMin_AmericanIndian',
#  'ACTSubtests_BenchmarksMet_AmericanIndian',
#  'EOCSubjects_CACR_AmericanIndian',
#  'GraduationRate_5yr_AmericanIndian',
#  'ACTCompositeScore_UNCMin_Asian',
#  'ACTSubtests_BenchmarksMet_Asian',
#  'ACTWorkKeys_SilverPlus_Asian',
#  'EOCBiology_CACR_Asian',
#  'EOCSubjects_CACR_Asian',
#  'GraduationRate_4yr_Asian',
#  'GraduationRate_5yr_Asian',
#  'ACTCompositeScore_UNCMin_Black',
#  'ACTSubtests_BenchmarksMet_Black',
#  'ACTWorkKeys_SilverPlus_Black',
#  'EOCBiology_CACR_Black',
#  'EOCEnglish2_CACR_Black',
#  'EOCMathI_CACR_Black',
#  'EOCSubjects_CACR_Black',
#  'GraduationRate_4yr_Black',
#  'ACTCompositeScore_UNCMin_Hispanic',
#  'ACTSubtests_BenchmarksMet_Hispanic',
#  'ACTWorkKeys_SilverPlus_Hispanic',
#  'EOCBiology_CACR_Hispanic',
#  'EOCEnglish2_CACR_Hispanic',
#  'EOCMathI_CACR_Hispanic',
#  'EOCSubjects_CACR_Hispanic',
#  'GraduationRate_4yr_Hispanic',
#  'GraduationRate_5yr_Hispanic',
#  'ACTCompositeScore_UNCMin_TwoorMoreRaces',
#  'ACTSubtests_BenchmarksMet_TwoorMoreRaces',
#  'ACTWorkKeys_SilverPlus_TwoorMoreRaces',
#  'EOCBiology_CACR_TwoorMoreRaces',
#  'EOCMathI_CACR_TwoorMoreRaces',
#  'EOCSubjects_CACR_TwoorMoreRaces',
#  'GraduationRate_4yr_TwoorMoreRaces',
#  'GraduationRate_5yr_TwoorMoreRaces',
#  'ACTCompositeScore_UNCMin_White',
#  'EOCBiology_CACR_White',
#  'EOCEnglish2_CACR_White',
#  'GraduationRate_4yr_White',
#  'GraduationRate_5yr_White',
#  'ACTCompositeScore_UNCMin_EDS',
#  'ACTWriting_ACTBenchmark_EDS',
#  'EOCBiology_CACR_EDS',
#  'GraduationRate_4yr_EDS',
#  'GraduationRate_5yr_EDS',
#  'ACTCompositeScore_UNCMin_LEP',
#  'ACTSubtests_BenchmarksMet_LEP',
#  'ACTWorkKeys_SilverPlus_LEP',
#  'ACTWriting_ACTBenchmark_LEP',
#  'EOCBiology_CACR_LEP',
#  'EOCEnglish2_CACR_LEP',
#  'EOCMathI_CACR_LEP',
#  'EOCSubjects_CACR_LEP',
#  'GraduationRate_4yr_LEP',
#  'GraduationRate_5yr_LEP',
#  'ACTCompositeScore_UNCMin_SWD',
#  'ACTMath_ACTBenchmark_SWD',
#  'ACTSubtests_BenchmarksMet_SWD',
#  'ACTWorkKeys_SilverPlus_SWD',
#  'ACTWriting_ACTBenchmark_SWD',
#  'EOCBiology_CACR_SWD',
#  'EOCEnglish2_CACR_SWD',
#  'EOCMathI_CACR_SWD',
#  'EOCSubjects_CACR_SWD',
#  'GraduationRate_4yr_SWD',
#  'ACTCompositeScore_UNCMin_AIG',
#  'ACTSubtests_BenchmarksMet_AIG',
#  'ACTWorkKeys_SilverPlus_AIG',
#  'EOCBiology_CACR_AIG',
#  'EOCEnglish2_CACR_AIG',
#  'EOCMathI_CACR_AIG',
#  'EOCSubjects_CACR_AIG',
#  'GraduationRate_4yr_AIG',
#  'GraduationRate_5yr_AIG',
#  'ACT_pTarget_PctMet',
#  'ACTWorkKeys_pTarget_PctMet',
#  'CurrentYearEOC_pTarget_PctMet',
#  'MathGr10_pTarget_PctMet',
#  'SciGr11_pTarget_PctMet',
#  'TotalTargets_pTarget_PctMet',
#  'sat_avg_score_num',
#  'lea_sat_avg_score_num',
#  'sat_participation_pct',
#  'lea_sat_participation_pct',
#  'ap_participation_pct',
#  'lea_ap_participation_pct',
#  'ap_pct_3_or_above',
#  'lea_ap_pct_3_or_above',
#  'total_specialized_courses',
#  'cte_courses',
#  'univ_college_courses',
#  'lea_cte_courses',
#  'lea_univ_college_courses',
#  'ALL_All Students (Total or Subtotal_ENROLL_sch_pct',
#  'ECODIS_Economically Disadvantaged_ENROLL_sch_pct',
#  'MB_Black_ENROLL_sch_pct',
#  'MW_White_ENROLL_sch_pct',
#  'avg_daily_attend_pct',
#  'crime_per_c_num',
#  'short_susp_per_c_num',
#  'long_susp_per_c_num',
#  'expelled_per_c_num',
#  'stud_internet_comp_num',
#  'lea_avg_daily_attend_pct',
#  'lea_crime_per_c_num',
#  'lea_short_susp_per_c_num',
#  'lea_long_susp_per_c_num',
#  'lea_expelled_per_c_num',
#  'lea_stud_internet_comp_num',
#  'st_avg_daily_attend_pct',
#  'st_crime_per_c_num',
#  'digital_media_pct',
#  'avg_age_media_collection',
#  'books_per_student',
#  'lea_books_per_student',
#  'wap_per_classroom',
#  'lea_wap_num',
#  'lea_wap_per_classroom',
#  'flicensed_teach_pct',
#  'tchyrs_0thru3_pct',
#  'tchyrs_4thru10_pct',
#  'tchyrs_11plus_pct',
#  'nbpts_num',
#  'advance_dgr_pct',
#  '_1yr_tchr_trnovr_pct',
#  'lateral_teach_pct',
#  'lea_flicensed_teach_pct',
#  'lea_tchyrs_0thru3_pct',
#  'lea_tchyrs_4thru10_pct',
#  'lea_tchyrs_11plus_pct',
#  'lea_nbpts_num',
#  'lea_advance_dgr_pct',
#  'lea_1yr_tchr_trnovr_pct',
#  'lea_emer_prov_teach_pct',
#  '0-3 Years_LEA_Exp_Pct_Prin',
#  '10+ Years_LEA_Exp_Pct_Prin',
#  '4-10 Years_LEA_Exp_Pct_Prin',
#  'Accomplished_TCHR_Standard 1_Pct',
#  'Accomplished_TCHR_Standard 2_Pct',
#  'Accomplished_TCHR_Standard 4_Pct',
#  'Accomplished_TCHR_Standard 5_Pct',
#  'Developing_TCHR_Standard 1_Pct',
#  'Developing_TCHR_Standard 2_Pct',
#  'Developing_TCHR_Standard 3_Pct',
#  'Developing_TCHR_Standard 4_Pct',
#  'Developing_TCHR_Standard 5_Pct',
#  'Distinguished_TCHR_Standard 1_Pct',
#  'Distinguished_TCHR_Standard 2_Pct',
#  'Does Not Meet Expected Growth_TCHR_Student Growth_Pct',
#  'Exceeds Expected Growth_TCHR_Student Growth_Pct',
#  'Meets Expected Growth_TCHR_Student Growth_Pct',
#  'Not Demostrated_TCHR_Standard 1_Pct',
#  'Not Demostrated_TCHR_Standard 2_Pct',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 4_Pct',
#  'Proficient_TCHR_Standard 1_Pct',
#  'AsianFemalePct',
#  'BlackMalePct',
#  'HispanicFemalePct',
#  'HispanicMalePct',
#  'IndianFemalePct',
#  'PacificIslandFemalePct',
#  'PacificIslandMalePct',
#  'TwoOrMoreFemalePct',
#  'TwoOrMoreMalePct',
#  'pct_eds',
#  'AAVC_Concentrator_Ct',
#  'AGNR_Concentrator_Ct',
#  'ARCH_Concentrator_Ct',
#  'BMA_Concentrator_Ct',
#  'HLTH_Concentrator_Ct',
#  'HOSP_Concentrator_Ct',
#  'INFO_Concentrator_Ct',
#  'MANU_Concentrator_Ct',
#  'STEM_Concentrator_Ct',
#  'TRAN_Concentrator_Ct',
#  'Number_Industry_Recognized_Crede',
#  'grade_range_cd_11-12',
#  'grade_range_cd_11-13',
#  'grade_range_cd_3-12',
#  'grade_range_cd_6-12',
#  'grade_range_cd_6-13',
#  'grade_range_cd_7-12',
#  'grade_range_cd_7-13',
#  'grade_range_cd_8-12',
#  'grade_range_cd_9-11',
#  'grade_range_cd_9-12',
#  'grade_range_cd_9-13',
#  'grade_range_cd_9-9',
#  'grade_range_cd_K-12',
#  'grade_range_cd_PK-12',
#  'grade_range_cd_PK-13',
#  'calendar_type_txt_Regular School, Year-Round Calendar',
#  'esea_status_P',
#  'Grad_project_status_Y',
#  'SBE District_Northeast',
#  'SBE District_Northwest',
#  'SBE District_Piedmont-Triad',
#  'SBE District_Sandhills',
#  'SBE District_Southeast',
#  'SBE District_Southwest',
#  'SBE District_Western',
#  'SPG Grade_A+NG',
#  'SPG Grade_B',
#  'SPG Grade_C',
#  'SPG Grade_D',
#  'Reading SPG Grade_B',
#  'Reading SPG Grade_C',
#  'Reading SPG Grade_D',
#  'Reading SPG Grade_F',
#  'Math SPG Grade_B',
#  'Math SPG Grade_C',
#  'Math SPG Grade_F',
#  'EVAAS Growth Status_Met',
#  'EVAAS Growth Status_NotMet',
#  'Byod_Yes',
#  'grades_BYOD_11:12',
#  'grades_BYOD_11:12:13',
#  'grades_BYOD_12',
#  'grades_BYOD_6:7:8:9:10:11:12',
#  'grades_BYOD_6:7:8:9:10:11:12:13',
#  'grades_BYOD_8:9:10:11:12',
#  'grades_BYOD_9',
#  'grades_BYOD_9:10:11',
#  'grades_BYOD_9:10:11:12',
#  'grades_BYOD_9:10:11:12:13',
#  'grades_BYOD_9:11:12',
#  'grades_BYOD_PK:9:10:11:12',
#  '_1_to_1_access_Yes',
#  'grades_1_to_1_access_10:11:12',
#  'grades_1_to_1_access_10:11:12:13',
#  'grades_1_to_1_access_11',
#  'grades_1_to_1_access_11:12',
#  'grades_1_to_1_access_11:12:13',
#  'grades_1_to_1_access_6:07:08',
#  'grades_1_to_1_access_6:7:8:9:10:11:12:13',
#  'grades_1_to_1_access_9',
#  'grades_1_to_1_access_9:10',
#  'grades_1_to_1_access_9:10:11',
#  'grades_1_to_1_access_9:10:11:12',
#  'grades_1_to_1_access_9:10:11:12:13',
#  'grades_1_to_1_access_9:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_10:11:12',
#  'SRC_Grades_Devices_Sent_Home_10:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12',
#  'SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_9:10',
#  'SRC_Grades_Devices_Sent_Home_9:10:12',
#  'unit_code']

# %%
dfDropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Columns: 279 entries, student_num to unit_code
# dtypes: float64(207), int64(72)
# memory usage: 1.0 MB

# %%
# Evenly split our target variable (predict whether a school will have 52% postsecondary enrollment)
splitLimit = 52
dfDropped['schoolPctTarget'] = np.where(dfDropped['ALL_All Students (Total or Subtotal_ENROLL_sch_pct'] >= splitLimit, 1, 0)
print("{} of {}: {}%".format(dfDropped['schoolPctTarget'].sum(), dfDropped.shape[0], 
                             round(dfDropped['schoolPctTarget'].sum()/dfDropped.shape[0] * 100,2)))
# Out:
# 239 of 470: 50.85%

# %% [markdown]
# ## Logistic Regresion, using data set reduced by correlation relation >.80

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'schoolPctTarget' in dfDropped:
    y = dfDropped['schoolPctTarget'].values # get the labels we want
    del dfDropped['schoolPctTarget'] # get rid of the class label
    X = dfDropped.values # use everything else to predict!

## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
#    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
# run logistic regression and vary some parameters
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt
from sklearn.preprocessing import StandardScaler

# first we create a reusable logisitic regression object
#   here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None) # get object

# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
    
# Also note that every time you run the above code
#   it randomly creates a new training and testing set, 
#   so accuracy will be different each time
# Out:
# ====Iteration 0  ====
# accuracy 0.8617021276595744
# confusion matrix
#  [[43  8]
#  [ 5 38]]
# ====Iteration 1  ====
# accuracy 0.8723404255319149
# confusion matrix
#  [[40  2]
#  [10 42]]
# ====Iteration 2  ====
# accuracy 0.8936170212765957
# confusion matrix
#  [[45  5]
#  [ 5 39]]

# %%
# here we can change some of the parameters interactively
from ipywidgets import widgets as wd

def lr_explor(cost):
    lr_clf = LogisticRegression(penalty='l2', C=cost, class_weight=None) # get object
    accuracies = cross_val_score(lr_clf,X,y=y,cv=cv_object) # this also can help with parallelism
    print(accuracies)

wd.interact(lr_explor,cost=(0.001,5.0,0.05),__manual=True)
# Out:
# interactive(children=(FloatSlider(value=2.451, description='cost', max=5.0, min=0.001, step=0.05), Output()), …
# <function __main__.lr_explor(cost)>

# %% [markdown]
# ## Interpret Weights

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=1, class_weight=None) # get object
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,dfDropped.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.776595744680851
# [[39 11]
#  [10 34]]
# GraduationRate_4yr_Asian has weight of -0.792558860687224
# GraduationRate_4yr_LEP has weight of -0.6904506644483233
# Accomplished_TCHR_Standard 5_Pct has weight of -0.688269108114995
# pct_eds has weight of -0.6632416125643942
# lea_advance_dgr_pct has weight of -0.5836554989011252
# wap_per_classroom has weight of -0.5553658373043187
# crime_per_c_num has weight of -0.4574488093739176
# PacificIslandFemalePct has weight of -0.4556551172370179
# ACT_pTarget_PctMet has weight of -0.4549493709314871
# Proficient_TCHR_Standard 1_Pct has weight of -0.4490231535088739
# EOCBiology_CACR_EDS has weight of -0.4396522189345977
# EOCEnglish2_CACR_SWD has weight of -0.4387035278803066
# esea_status_P has weight of -0.43728831543880786
# SBE District_Sandhills has weight of -0.41669402204518985
# lea_supplies_expense_pct has weight of -0.4063656774650561
# Exceeds Expected Growth_TCHR_Student Growth_Pct has weight of -0.4014729885997455
# GraduationRate_4yr_SWD has weight of -0.39395019092381445
# grade_range_cd_8-12 has weight of -0.3828624767947612
# ACTSubtests_BenchmarksMet_Asian has weight of -0.37967621599102885
# ACTCompositeScore_UNCMin_Black has weight of -0.37638491829538506
# TwoOrMoreFemalePct has weight of -0.3744047374291931
# EOCEnglish2_CACR_AIG has weight of -0.37072893001695506
# GraduationRate_4yr_Hispanic has weight of -0.3592141513940584
# tchyrs_0thru3_pct has weight of -0.35457326476059114
# Not Demostrated_TCHR_Standard 4_Pct has weight of -0.3449197444263
# EOCBiology_CACR_Hispanic has weight of -0.3384262118016009
# grade_range_cd_PK-12 has weight of -0.33016672306249656
# Developing_TCHR_Standard 2_Pct has weight of -0.3267600302545876
# GraduationRate_5yr_EDS has weight of -0.3174953333989124
# lea_cte_courses has weight of -0.31694176859095524
# 11_Size has weight of -0.2938778899399567
# ACTWorkKeys_SilverPlus_TwoorMoreRaces has weight of -0.2903668455215821
# Passing NC Math 3 has weight of -0.28258880473903686
# English II Score has weight of -0.27876195294627887
# 10+ Years_LEA_Exp_Pct_Prin has weight of -0.2719928392584135
# lea_expelled_per_c_num has weight of -0.27164126827310275
# lea_crime_per_c_num has weight of -0.27068842473830745
# EOCEnglish2_CACR_White has weight of -0.26290039049208913
# BMA_Concentrator_Ct has weight of -0.2604571092492748
# GraduationRate_4yr_Black has weight of -0.2600532554280713
# MANU_Concentrator_Ct has weight of -0.2590420957830405
# PacificIslandMalePct has weight of -0.25711840516342055
# ARCH_Concentrator_Ct has weight of -0.25084910715433156
# EOCBiology_CACR_TwoorMoreRaces has weight of -0.24520062041696977
# EOCSubjects_CACR_SWD has weight of -0.24253026203612066
# long_susp_per_c_num has weight of -0.2300977900574519
# Biology_Size has weight of -0.22847403053571763
# grades_BYOD_8:9:10:11:12 has weight of -0.22533858627167172
# grades_BYOD_PK:9:10:11:12 has weight of -0.2202204447248345
# SRC_Grades_Devices_Sent_Home_10:11:12 has weight of -0.2201065893479241
# EOCMathI_CACR_SWD has weight of -0.21188822958820175
# ACTSubtests_BenchmarksMet_AIG has weight of -0.20342417861364004
# EOCBiology_CACR_White has weight of -0.20243452101912518
# lea_ap_participation_pct has weight of -0.20181579464966332
# AAVC_Concentrator_Ct has weight of -0.19979479960325935
# lea_sat_participation_pct has weight of -0.19808272975913213
# TRAN_Concentrator_Ct has weight of -0.19729513276416236
# grades_1_to_1_access_9:10 has weight of -0.19725313138182354
# student_num has weight of -0.19203586592870556
# SPG Grade_C has weight of -0.1891060906649952
# EOCSubjects_CACR_LEP has weight of -0.18712491985901003
# books_per_student has weight of -0.1794746896473083
# grades_1_to_1_access_9:10:11:12 has weight of -0.17362872395528728
# EOCEnglish2_CACR_Black has weight of -0.17190734026423954
# digital_media_pct has weight of -0.16862194193747906
# EOCSubjects_CACR_AIG has weight of -0.16542357969101437
# Accomplished_TCHR_Standard 2_Pct has weight of -0.16506318982909762
# grade_range_cd_9-13 has weight of -0.16099524083096303
# st_avg_daily_attend_pct has weight of -0.15769519991477635
# lea_emer_prov_teach_pct has weight of -0.15526844389745229
# lea_services_expense_pct has weight of -0.15330809129523196
# GraduationRate_5yr_AmericanIndian has weight of -0.15199272950420267
# EOCEnglish2_CACR_LEP has weight of -0.14427157109853364
# lea_long_susp_per_c_num has weight of -0.13995152653465467
# Developing_TCHR_Standard 5_Pct has weight of -0.1396348110601318
# ACTCompositeScore_UNCMin_AIG has weight of -0.13614814400863717
# SRC_Grades_Devices_Sent_Home_9:10:12 has weight of -0.13461770796223135
# grades_BYOD_9:10:11:12 has weight of -0.13200640694241558
# EVAAS Growth Status_Met has weight of -0.13200419178797299
# CurrentYearEOC_pTarget_PctMet has weight of -0.13037023576913015
# lea_tchyrs_4thru10_pct has weight of -0.13015418643731408
# Byod_Yes has weight of -0.12791788950941985
# Distinguished_TCHR_Standard 2_Pct has weight of -0.11900369385605174
# avg_age_media_collection has weight of -0.10427866261526363
# grade_range_cd_7-12 has weight of -0.10297581171055625
# grade_range_cd_6-12 has weight of -0.10199038621114012
# grades_BYOD_11:12 has weight of -0.10160933208571421
# SBE District_Southwest has weight of -0.0992550644658773
# ACTCompositeScore_UNCMin_TwoorMoreRaces has weight of -0.09568905606900485
# 09_Size has weight of -0.09518162785275072
# lea_total_expense_num has weight of -0.09430808810909284
# SBE District_Northeast has weight of -0.09330872244513745
# grades_1_to_1_access_6:07:08 has weight of -0.08951677669456398
# ACTWorkKeys_pTarget_PctMet has weight of -0.0891165519846523
# Math SPG Grade_C has weight of -0.08551143521183531
# Reading SPG Grade_C has weight of -0.08507005189452134
# MathGr10_pTarget_PctMet has weight of -0.08077161980251012
# lea_books_per_student has weight of -0.0803871616423585
# GraduationRate_5yr_AIG has weight of -0.06945916683012394
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct has weight of -0.06555291690506376
# Not Demostrated_TCHR_Standard 3_Pct has weight of -0.0642110574050474
# GraduationRate_5yr_White has weight of -0.061860995322329235
# total_specialized_courses has weight of -0.05927790310434294
# grades_BYOD_6:7:8:9:10:11:12 has weight of -0.05834561239559476
# grades_BYOD_12 has weight of -0.058316896327406866
# cte_courses has weight of -0.057591370620286506
# SPG Grade_A+NG has weight of -0.05333982222973888
# lea_local_perpupil_num has weight of -0.045784534241989056
# EVAAS Growth Status_NotMet has weight of -0.03318687097172528
# ACTMath_ACTBenchmark_SWD has weight of -0.032941531008617284
# Number_Industry_Recognized_Crede has weight of -0.028153445337228133
# Developing_TCHR_Standard 3_Pct has weight of -0.01846035773177133
# ACTCompositeScore_UNCMin_SWD has weight of -0.01828053085827104
# Reading SPG Grade_D has weight of -0.014819030407170362
# ACTSubtests_BenchmarksMet_SWD has weight of -0.012642083045933781
# lea_tchyrs_0thru3_pct has weight of -0.01238260768010051
# ACTSubtests_BenchmarksMet_LEP has weight of -0.011737135663219008
# grade_range_cd_9-9 has weight of -0.008222630395027016
# grade_range_cd_7-13 has weight of -0.0068147144532899745
# ACTCompositeScore_UNCMin_Asian has weight of -0.006801964080986026
# ACTSubtests_BenchmarksMet_AmericanIndian has weight of -0.004182451260847727
# Grad_project_status_Y has weight of -0.0008421539523590446
# ACTWorkKeys_SilverPlus_LEP has weight of 0.0
# grades_1_to_1_access_11:12 has weight of 0.0
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12 has weight of 0.001682018354309255
# Reading SPG Grade_B has weight of 0.0024173903806978935
# GraduationRate_4yr_TwoorMoreRaces has weight of 0.0028745415135069926
# EOCSubjects_CACR_Asian has weight of 0.0029700865535273136
# univ_college_courses has weight of 0.004016712048508675
# grades_BYOD_9 has weight of 0.004855462728494538
# grades_1_to_1_access_6:7:8:9:10:11:12:13 has weight of 0.0049012003080378804
# grade_range_cd_11-13 has weight of 0.005602732600051098
# grades_1_to_1_access_11 has weight of 0.005602732600051098
# grade_range_cd_3-12 has weight of 0.0056800110764643925
# grades_1_to_1_access_10:11:12:13 has weight of 0.00574257052507017
# grades_BYOD_9:10:11 has weight of 0.005866879138237127
# lea_flicensed_teach_pct has weight of 0.0075032782187086046
# grades_1_to_1_access_11:12:13 has weight of 0.007896738412041178
# grades_BYOD_11:12:13 has weight of 0.007928623075539046
# SRC_Grades_Devices_Sent_Home_10:11:12:13 has weight of 0.00800117400581811
# calendar_type_txt_Regular School, Year-Round Calendar has weight of 0.008041415121965606
# grade_range_cd_9-11 has weight of 0.008073296720681076
# 12_Size has weight of 0.016886510118522678
# _1_to_1_access_Yes has weight of 0.017243678934740582
# Distinguished_TCHR_Standard 1_Pct has weight of 0.018798049231118774
# Math SPG Grade_F has weight of 0.02149983811723592
# lateral_teach_pct has weight of 0.021746975327205414
# grades_BYOD_9:11:12 has weight of 0.022748998859645472
# ACTWriting_ACTBenchmark_EDS has weight of 0.024191401394048996
# grades_1_to_1_access_9:10:11:12:13 has weight of 0.02502360295322957
# ACTCompositeScore_UNCMin_AmericanIndian has weight of 0.034574713758169826
# SPG Grade_B has weight of 0.03464985609879568
# EOCMathI_CACR_LEP has weight of 0.03576772909905104
# Not Demostrated_TCHR_Standard 1_Pct has weight of 0.042810360244098
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13 has weight of 0.04391485109938888
# grade_range_cd_11-12 has weight of 0.04630162151664258
# stud_internet_comp_num has weight of 0.04778039773100423
# st_crime_per_c_num has weight of 0.051386673183064356
# Reading SPG Grade_F has weight of 0.051982865054950235
# advance_dgr_pct has weight of 0.05246147856260172
# SBE District_Western has weight of 0.05396473809966845
# EOCSubjects_CACR_Black has weight of 0.057280134164394314
# ACTWorkKeys_SilverPlus_SWD has weight of 0.06033263777127412
# grades_1_to_1_access_9:11:12:13 has weight of 0.06181830486626923
# TwoOrMoreMalePct has weight of 0.06437078255373799
# 10_Size has weight of 0.06447746793500753
# grade_range_cd_6-13 has weight of 0.06681613920801754
# 0-3 Years_LEA_Exp_Pct_Prin has weight of 0.06706696176591243
# Biology Score has weight of 0.06729361520898917
# SciGr11_pTarget_PctMet has weight of 0.06826375660781812
# GraduationRate_5yr_Male has weight of 0.0689062298187937
# ACTCompositeScore_UNCMin_EDS has weight of 0.07144970962268336
# flicensed_teach_pct has weight of 0.07180657625248517
# grade_range_cd_PK-13 has weight of 0.07698301003436187
# Developing_TCHR_Standard 1_Pct has weight of 0.07784796323042106
# grades_BYOD_6:7:8:9:10:11:12:13 has weight of 0.0782529464242673
# lea_nbpts_num has weight of 0.07855208723719379
# sat_participation_pct has weight of 0.08075944843736081
# nbpts_num has weight of 0.08758431804555697
# GraduationRate_5yr_Hispanic has weight of 0.08772178654212644
# Accomplished_TCHR_Standard 4_Pct has weight of 0.08778531869248261
# sat_avg_score_num has weight of 0.09058525206708212
# lea_tchyrs_11plus_pct has weight of 0.09217329171850534
# AsianFemalePct has weight of 0.09640999517885726
# lea_1yr_tchr_trnovr_pct has weight of 0.09739298765775836
# GraduationRate_5yr_Asian has weight of 0.0974626707257166
# HispanicFemalePct has weight of 0.10091378861968259
# lea_avg_daily_attend_pct has weight of 0.10124332638579765
# ACT WorkKeys Score has weight of 0.10320357708577553
# EOCMathI_CACR_Hispanic has weight of 0.10426531124030101
# 4-10 Years_LEA_Exp_Pct_Prin has weight of 0.10768861565359028
# TotalTargets_pTarget_PctMet has weight of 0.11580180360962126
# st_avg_student_num has weight of 0.1183621284818107
# SPG Grade_D has weight of 0.11873238217740278
# EVAAS Growth Score has weight of 0.11994805049740355
# NC Math 1 Score has weight of 0.12088338166242373
# Math SPG Grade_B has weight of 0.12106434745656446
# ACTCompositeScore_UNCMin_Hispanic has weight of 0.12286364531575149
# AGNR_Concentrator_Ct has weight of 0.12369485779707964
# grades_BYOD_9:10:11:12:13 has weight of 0.12650960848419968
# SRC_Grades_Devices_Sent_Home_9:10 has weight of 0.12715868206152686
# lea_wap_num has weight of 0.1317779179241632
# GraduationRate_4yr_Female has weight of 0.13361635532292257
# ACTSubtests_BenchmarksMet_TwoorMoreRaces has weight of 0.13943807671168834
# tchyrs_4thru10_pct has weight of 0.14025325245249126
# EOCBiology_CACR_SWD has weight of 0.14390219888604924
# ACTCompositeScore_UNCMin_White has weight of 0.14632484565683476
# GraduationRate_4yr_Male has weight of 0.14867005669305586
# SPG Score has weight of 0.1499729348330144
# ACTWorkKeys_SilverPlus_Black has weight of 0.15024314239908598
# grade_range_cd_K-12 has weight of 0.1527390883510356
# EOCBiology_CACR_AIG has weight of 0.16474214756440766
# _1yr_tchr_trnovr_pct has weight of 0.16518326907941477
# ACTWriting_ACTBenchmark_SWD has weight of 0.16561118169777833
# HLTH_Concentrator_Ct has weight of 0.165853773409527
# lea_univ_college_courses has weight of 0.17424873136468377
# lea_avg_student_num has weight of 0.1846426457179157
# Not Demostrated_TCHR_Standard 2_Pct has weight of 0.18486775953400558
# lea_sat_avg_score_num has weight of 0.18757921261019722
# expelled_per_c_num has weight of 0.19051548328070872
# GraduationRate_5yr_All has weight of 0.19379633361414997
# ACTWorkKeys_SilverPlus_Hispanic has weight of 0.1968854528183315
# SBE District_Northwest has weight of 0.20477525826480264
# unit_code has weight of 0.20994709117658925
# ap_pct_3_or_above has weight of 0.21092003875888682
# Meets Expected Growth_TCHR_Student Growth_Pct has weight of 0.21206121340362946
# tchyrs_11plus_pct has weight of 0.2126997179393064
# HOSP_Concentrator_Ct has weight of 0.2206736902412182
# EOCMathI_CACR_TwoorMoreRaces has weight of 0.22219474514077586
# ap_participation_pct has weight of 0.22298516177200106
# grades_1_to_1_access_9:10:11 has weight of 0.22344625040610597
# GraduationRate_4yr_White has weight of 0.22713923890192786
# lea_instruct_equip_exp_pct has weight of 0.23272810572463093
# STEM_Concentrator_Ct has weight of 0.2380747908846002
# ACTSubtests_BenchmarksMet_Black has weight of 0.25370966722378685
# EOCSubjects_CACR_TwoorMoreRaces has weight of 0.254935708713135
# GraduationRate_5yr_LEP has weight of 0.2553809707790268
# GraduationRate_5yr_TwoorMoreRaces has weight of 0.2559015846745292
# grade_range_cd_9-12 has weight of 0.25638917002218414
# grades_1_to_1_access_9 has weight of 0.25828751948084544
# GraduationRate_4yr_EDS has weight of 0.25988131639915224
# ACTWriting_ACTBenchmark_LEP has weight of 0.2650504728656075
# EOCSubjects_CACR_Hispanic has weight of 0.2653574899192573
# lea_salary_expense_pct has weight of 0.2729176169792664
# lea_stud_internet_comp_num has weight of 0.273451784231141
# short_susp_per_c_num has weight of 0.27372974593073873
# grades_1_to_1_access_10:11:12 has weight of 0.27492253869279515
# ACTWorkKeys_SilverPlus_Asian has weight of 0.2759711831634686
# Developing_TCHR_Standard 4_Pct has weight of 0.2816404720870661
# GraduationRate_4yr_AIG has weight of 0.2832076734687394
# lea_ap_pct_3_or_above has weight of 0.2974675733096059
# lea_wap_per_classroom has weight of 0.3117555372545628
# avg_daily_attend_pct has weight of 0.32219380585469193
# EOCMathI_CACR_Black has weight of 0.32482741021528566
# SBE District_Piedmont-Triad has weight of 0.33392826154671323
# EOCMathI_CACR_AIG has weight of 0.34772386852762344
# INFO_Concentrator_Ct has weight of 0.3497330128718086
# EOCBiology_CACR_LEP has weight of 0.351846416624075
# ACT Score has weight of 0.37038511000453367
# Math I_Size has weight of 0.37838668255866853
# HispanicMalePct has weight of 0.3808176520648874
# ACTSubtests_BenchmarksMet_Hispanic has weight of 0.3841111158081966
# lea_short_susp_per_c_num has weight of 0.38719953838923304
# EOCSubjects_CACR_AmericanIndian has weight of 0.4039628095424405
# lea_federal_perpupil_num has weight of 0.4084664779537959
# BlackMalePct has weight of 0.41073853211302824
# ACTCompositeScore_UNCMin_LEP has weight of 0.41228990582665787
# EOCBiology_CACR_Asian has weight of 0.5015611899207487
# Accomplished_TCHR_Standard 1_Pct has weight of 0.5363969661459321
# ACTWorkKeys_SilverPlus_AIG has weight of 0.5634029897083712
# EOCEnglish2_CACR_Hispanic has weight of 0.5731031100350484
# EOCBiology_CACR_Black has weight of 0.591229191412012
# SBE District_Southeast has weight of 0.593662530510797
# English II_Size has weight of 0.5944718608919674
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct has weight of 0.6061460350919422
# IndianFemalePct has weight of 0.7493330776592111
# MB_Black_ENROLL_sch_pct has weight of 0.7815651944919424
# MW_White_ENROLL_sch_pct has weight of 1.801985863402326
# ALL_All Students (Total or Subtotal_ENROLL_sch_pct has weight of 3.1846166579788897

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=dfDropped.columns)
weights.plot(kind='bar')
plt.show()

# %% [markdown]
# ## Create Models (50 points)
# <span style="color: blue">Create a logistic regression model and a support vector machine model for the classification task involved with your dataset. Assess how well each model performs (use 80/20 training/testing split for your data). <b>Adjust parameters of the models to make them more accurate.</b> If your dataset size requires the use of stochastic gradient descent, then linear kernel only is fine to use. That is, the SGDClassifier is fine to use for optimizing logistic regression and linear support vector machines. For many problems, SGD will be required in order to train the SVM model in a reasonable timeframe.

# %% [markdown]
# ## Model Advantages (10 points)
# <span style="color: blue">Discuss the advantages of each model for each classification task. Does one type of model offer superior performance over another in terms of prediction accuracy? In terms of training time or efficiency? Explain in detail.</span>

# %% [markdown]
# ## Interpret Feature Importance (30 points)
#
# <span style="color: blue">Use the weights from logistic regression to interpret the importance of different features for the classification task. <b>Explain your interpretation in detail.</b>Why do you think some variables are more important?

# %% [markdown]
# ## Interpret Support Vectors (10 points)
# <span style="color:blue">Look at the chosen support vectors for the classification task. Do these provide any insight into the data? Explain. If you used stochastic gradient descent (and therefore did not explicitly solve for support vectors), try subsampling your data to train the SVC model— then analyze the support vectors from the subsampled dataset.
